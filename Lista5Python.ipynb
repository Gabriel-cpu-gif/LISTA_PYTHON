# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriel-cpu-gif/LISTA_PYTHON/blob/main/Lista5Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Probabilidade e Estatística;
# Gabriel Euller;
#Lista 5;

'''1 - Uma amostra de gauchos foi investigada em relação ao consumo de sal diario, obtendo-se o seguinte:
Escreva em python uma lista com valores mostrados acima e calcule
import statistics

x = [10, 13, 17, 9, 8, 11, 13, 7]
print(statistics.mean(x)) # CALCULA MEDIA
print(statistics.mode(x)) # CALCULA MODA
print(statistics.harmonic_mean(x)) # MEDIA HARMONICA
print(statistics.gmean) # MEDIA GEOMETRICA
print(statistics.variance(x)) # CALCULA VARIANÇA
print(statistics.stdev(x)) # CALCULA DESVIO PADRAO 
'''


'''-----------------------------------------------------------------------'''



''' 2 - Os resultados baseados em uma escala de ansiedade para uma amostra de nove sujeitos são:
Escreva em python uma lista com os valores mostrados acima e calcule:

import statistics
x = [67, 75, 63, 72, 77, 78, 81, 77, 80]
print(statistics.mean(x)) # CALCULA MEDIA
print(statistics.mode(x)) # CALCULA MODA
print(statistics.median(x)) # CALCULA MEDIANA
print(statistics.variance(x)) # CALCULA VARIANÇA
print(statistics.stdev(x)) # CALCULA DESVIO PADRAO
print(statistics.gmean(x)) # CALCULA VARIANÇA '''


'''----------------------------------------------------------------------'''

'''3 - Os dados em rol relacionados a seguir referem-se a producao diaria de
leite de vacas da raca Holandesa obtida em duas ordenhas, em kg
calcule o coeficiente de variacao desse conjunto
import statistics


lista = [4.0, 4.5, 5.0, 5.5, 6.0, 6.0, 6.5, 6.5, 6.5, 6.5,
         7.0, 7.0, 7.0,7.0, 7.0, 7.0, 7.5, 8.5, 9.0, 9.0,
         9.0, 10.0, 10,0, 10.5, 10.5, 11.0, 12.0, 13.0, 13.0]
print(statistics.mean(lista)) # CALCULA MEDIA
print(statistics.mode(lista)) # CALCULA MODA
print(statistics.median(lista)) # CALCULA MEDIANA
print(statistics.variance(lista)) # CALCULA VARIANÇA
print(statistics.stdev(lista)) # CALCULA DESVIO PADRAO
#print(statistics.gmean(lista)) # CALCULA VARIANÇA '''
'''



'''---------------------------------------------------------------------'''

'''4 - A tabela seguinte apresenta a producao de cafe, em milhoes de toneladass,
na regiao delta

'''Ano1 = float(input("Digite o 1 ano:"))
ton1 = float(input("ton 1:"))
 
Ano2 = float(input("Digite o 2 ano:"))
ton2 = float(input("ton 2:"))

Ano3 = float(input("Digite o 3 ano:"))
ton3 = float(input("ton 3:"))

Ano4 = float(input("Digite o 4 ano:"))
ton4 = float(input("ton 4:"))

Ano5 = float(input("Digite o 5 ano:"))
ton5 = float(input("ton 5:"))

Ano6 = float(input("Digite o 6 ano:"))
ton6 = float(input("ton 6:"))

Ano7 = float(input("Digite o 7 ano:"))
ton7 = float(input("ton 7:"))

Ano8 = float(input("Digite o 8 ano:"))
ton8 = float(input("ton 8:"))

Ano9 = float(input("Digite o 9 ano:"))
ton9 = float(input("ton 9:"))

Ano10 = float(input("Digite o 10 ano:"))
ton10 = float(input("ton 10:"))'''

 
'''calcula = (Ano1*ton1 + Ano2*ton2 + Ano3*ton3 + Ano4*ton4 + Ano5*ton5 + 
Ano6*ton6 + Ano7*ton7 + Ano8*ton8 + Ano9*ton9 + Ano10*ton10)
/ (ton1+ton2+ton3+ton4+ton5+ton6+ton7+ton8+ton9+ton10)
 #imprime a média
print("calcula:",calcula)
print(statistics.mean(x)) # CALCULA MEDIA
print(statistics.stdev(x)) # CALCULA DESVIO PADRAO'''



''' -------------------------------------------------------------------'''


''' 5. Escreva em Python um algoritmo que solicite para o usuário inserir
notas de alunos entre 0 e 10 em um loop infinito com condição de
parada uma nota igual a -999. A cada iteração valide que a nota seja
entre 0 e 10 e solicite uma nota correta em caso de erro.
Após obter todas as notas, o programa deve mostrar:

variavel = int(input("Digite um numero de 0 a 10:"))

if variavel > 10 or variavel < 0:
  print("Nota invalida, digite uma nota entre 0 e 10")
else:
  while true:
    print("Deseja continuar? caso não digite -999")
    variavel2 = float(input("Digite uma nota")
if variavel2 == '-999':
  break
  print(statistics.mean(variavel,variavel2))  # CALCULA MEDIA
  print(statistics.harmonic_mean(variavel,variavel2)) # MEDIA HARMONICA
  print(statistics.gmean) # MEDIA GEOMETRICA
  print(statistics.mode(variavel,variavel2)) # CALCULA MODA
  print(statistics.variance(variavel,variavel2)) # CALCULA VARIANÇA
  print(statistics.stdev(variavel,variavel2))'''
   
'''---------------------------------------------------------------------'''


 
'''6. Escreva em Python um algoritmo que solicite para o usuário inserir 3
notas de um aluno (entre 0 e 10)
O programa deve calcular a média ponderada com os pesos 3, 4 e 3
para as 3 notas recebidas.
# digita as notas e os pesos
nota1 = float(input("Nota 1:"))
peso1 = float(input("Peso 1:"))
 
nota2 = float(input("Nota 2:"))
peso2 = float(input("Peso 2:"))

nota3 = float(input("Nota 3:"))
peso3 = float(input("Peso 3:"))
 
# calcula média
media = (nota1*peso1 + nota2*peso2) / (peso1+peso2)
 
# imprime a média
print("Média: ",media'''
